# %%
__Description__= "The following notebook presents the chaos game"
__author__ = "Rangel Rivera Ulises Osmar"
__copyright__ = ""
__credits__ = ["Rangel Ulises and numberphile"]
__license__ = ""
__version__ = "1.0"
__maintainer__ = "Rangel Rivera Ulises Osmar"
__email__ = "uli.osmr@gmail.com"
__status__ = "Finished"

# %% [markdown]
# # The chaos game
#
# The chaos game is a simple dynamic  where:
#
# 1. You choose 3 points in a plane so they form a triangle it doesn't matter what kind they just have to form one, once we have our vertices A, B and C we can join them to form the boundary of our game board.
#
# 2. Once we have our triangle we can choose a point at random as our starting position.
#
# 3. Now we assign each vertex of our triangle a pair of values from a 6 sided dice where each side has a dot in it (e.g A has the sides with 1 and 2 dots, B 3 dots and 4 dots and C 5 dots and 6 dots) once we do this we can roll our dice.
#
# 4. Depending of the face up value of our dice we will choose a point half way between our starting point and the vertex assigned to that value on our dice, now our starting point will be this new location
#
# 5. we repeat step 4 until something cool appears.

# %% [markdown]
# # Variations
#
# Now we will introduce a second board to see what the process makes, I'll start by introducing 2 triangles, then a triangle and a square, in every case we will have the dynamic playout in two ways, one with restrictions and one without.

# %%
# first some libraries as always

import matplotlib.pyplot as plt
import numpy as np

# %%
# distance value

d = 0.4

#d = 0.15

#d = 0.25

#d = 0.61

# d = 0.75

# d = 0.43

# %%
# triangles

tri_a = [[65,105,25,65],[120,20,20,120]]

#cuad = [[60,100,60,20,60],[40,80,120,80,40]]

#cuad_b = [[160,220,220,160,160],[40,40,100,100,40]]

tri_b = [[140,160,200,140],[120,40,60,120]]

# fig, ax = plt.subplots(facecolor = 'white' , figsize=(7,7))
# ax.set_title("Sierpinski Gasket",color = 'black' )
# plt.plot(cuad_b[0],cuad_b[1], 'o-k')
# plt.plot(cuad[0],cuad[1], 'o-k')
# plt.axis('off')
# plt.show()

# %%
# initial point
i_px = 2
i_py = 5

# we define where we will store stuff

p_x = []
p_y = []

# we store our initial values
p_x.append(i_px)
p_y.append(i_py)

# %%
# double triangle loop without restrictions

np.random.seed(18)

for i in range(3000):
    
    dice_r = np.random.randint(1,7,dtype=int)

    if dice_r == 1:
            
            s_x = round(tri_a[0][0] + i_px, 4)
            s_y = round(tri_a[1][0] + i_py, 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 2:

            s_x = round(tri_a[0][1] + i_px, 4)
            s_y = round(tri_a[1][1] + i_py, 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 3:

            s_x = round(i_px + tri_a[0][2], 4)
            s_y = round(i_py + tri_a[1][2], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 4:
            
            s_x = round(i_px + tri_b[0][0], 4)
            s_y = round(i_py + tri_b[1][0], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 5:
           
            s_x = round(i_px + tri_b[0][1], 4)
            s_y = round(i_py + tri_b[1][1], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y
            
    elif dice_r == 6:
           
            s_x = round(i_px + tri_b[0][2], 4)
            s_y = round(i_py + tri_b[1][2], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

# %%
# double triangle with restrictions

np.random.seed(18)

pre_roll = np.random.randint(1,7,dtype=int)

for i in range(8000):
    
    dice_r = np.random.randint(1,7,dtype=int)
    ctrl = 0

    if dice_r == pre_roll:

        while dice_r == pre_roll:

            ctrl += 1
            dice_r = np.random.randint(1,7,dtype=int)

            if dice_r != pre_roll:
                break
            elif ctrl > 10:
                break
            else:
                pass
    else:
        pass

    pre_roll = dice_r

    if dice_r == 1:
            
            s_x = round(tri_a[0][0] + i_px, 4)
            s_y = round(tri_a[1][0] + i_py, 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 2:

            s_x = round(tri_a[0][1] + i_px, 4)
            s_y = round(tri_a[1][1] + i_py, 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 3:

            s_x = round(i_px + tri_a[0][2], 4)
            s_y = round(i_py + tri_a[1][2], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 4:
            
            s_x = round(i_px + tri_b[0][0], 4)
            s_y = round(i_py + tri_b[1][0], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 5:
           
            s_x = round(i_px + tri_b[0][1], 4)
            s_y = round(i_py + tri_b[1][1], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y
            
    elif dice_r == 6:
           
            s_x = round(i_px + tri_b[0][2], 4)
            s_y = round(i_py + tri_b[1][2], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

# %%
# triangle and square with restrictions

np.random.seed(18)

pre_roll = np.random.randint(1,8,dtype=int)

for i in range(8000):
    
    dice_r = np.random.randint(1,8,dtype=int)
    ctrl = 0

    if dice_r == pre_roll:

        while dice_r == pre_roll:

            ctrl += 1
            dice_r = np.random.randint(1,8,dtype=int)

            if dice_r != pre_roll:
                break
            elif ctrl > 10:
                break
            else:
                pass
    else:
        pass

    pre_roll = dice_r

    if dice_r == 1:
            
            s_x = round(tri_a[0][0] + i_px, 4)
            s_y = round(tri_a[1][0] + i_py, 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 2:

            s_x = round(tri_a[0][1] + i_px, 4)
            s_y = round(tri_a[1][1] + i_py, 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 3:

            s_x = round(i_px + tri_a[0][2], 4)
            s_y = round(i_py + tri_a[1][2], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 4:
            
            s_x = round(i_px + cuad[0][0], 4)
            s_y = round(i_py + cuad[1][0], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 5:
           
            s_x = round(i_px + cuad[0][1], 4)
            s_y = round(i_py + cuad[1][1], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y
            
    elif dice_r == 6:
           
            s_x = round(i_px + cuad[0][2], 4)
            s_y = round(i_py + cuad[1][2], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 7:

            s_x = round(i_px + cuad[0][3], 4)
            s_y = round(i_py + cuad[1][3], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

# %%
# double square with restrictions

np.random.seed(18)

pre_roll = np.random.randint(1,9,dtype=int)

for i in range(8000):
    
    dice_r = np.random.randint(1,9,dtype=int)
    ctrl = 0

    if dice_r == pre_roll:

        while dice_r == pre_roll:

            ctrl += 1
            dice_r = np.random.randint(1,9,dtype=int)

            if dice_r != pre_roll:
                break
            elif ctrl > 10:
                break
            else:
                pass
    else:
        pass

    pre_roll = dice_r

    if dice_r == 1:
            
            s_x = round(cuad_b[0][0] + i_px, 4)
            s_y = round(cuad_b[1][0] + i_py, 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 2:

            s_x = round(cuad_b[0][1] + i_px, 4)
            s_y = round(cuad_b[1][1] + i_py, 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 3:

            s_x = round(i_px + cuad_b[0][2], 4)
            s_y = round(i_py + cuad_b[1][2], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 4:
            
            s_x = round(i_px + cuad_b[0][3], 4)
            s_y = round(i_py + cuad_b[1][3], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 5:
           
            s_x = round(i_px + cuad[0][0], 4)
            s_y = round(i_py + cuad[1][0], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y
            
    elif dice_r == 6:
           
            s_x = round(i_px + cuad[0][1], 4)
            s_y = round(i_py + cuad[1][1], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 7:

            s_x = round(i_px + cuad[0][2], 4)
            s_y = round(i_py + cuad[1][2], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

    elif dice_r == 8:

            s_x = round(i_px + cuad[0][3], 4)
            s_y = round(i_py + cuad[1][3], 4)

            c_x = round((s_x*d), 4)
            c_y = round((s_y*d), 4)

            p_x.append(c_x)
            p_y.append(c_y)

            i_px = c_x
            i_py = c_y

# %%
# transforming results to plot them
p_x = np.array(p_x).reshape(-1,1)
p_y = np.array(p_y).reshape(-1,1)
dots = np.hstack((p_x,p_y))

# %%
# triangle graph

fig, ax = plt.subplots(facecolor = 'black' , figsize=(7,7))
ax.set_title("Sierpinski Gasket",color = 'w' )
#plt.plot(tri[0],tri[1], 'o-k')
plt.scatter(dots[:,0],dots[:,1],s=1, c = dots[:,1], cmap = plt.get_cmap("plasma"),
            alpha = 0.9)
plt.axis('off')
plt.show()
